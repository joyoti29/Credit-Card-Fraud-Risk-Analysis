# %% [markdown]
# DATA CLEANING & EDA

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the Data
df = pd.read_csv('E:/Project1/Credit Card Risk/Credit Card Fraud Risk Analysis.csv')

print(df.shape)
print(df.head())
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (1000, 14)
#    Transaction ID  Customer Name Merchant Name Transaction Date  \
# 0        17797619     Pihu Manne          Uber       2024-11-10
# 1        50040671   Hiran Vaidya        Zomato       2024-05-20
# 2        88177651     Shalv Vasa        Myntra       2024-05-28
# 3        24228305  Taran Shanker     Lifestyle       2024-01-09
# 4        87307869   Shanaya Kara     Tata Cliq       2024-07-27
#
#    Transaction Amount (INR) Fraud Risk        Fraud Type          State  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
#
#   Card Type          Bank  IsFraud  Fraud Score Transaction Category  \
# 0     Rupay    ICICI Bank        0           57       Transportation
# 1      Amex           SBI        0           10            Groceries
# 2      Visa     HDFC Bank        0           55       Transportation
# 3      Visa  Federal Bank        0           30           E-commerce
# 4      Amex           SBI        0           86          Electronics
#
#   Merchant Location
# 0         Bangalore
# 1         Bangalore
# 2         Ahmedabad
# 3           Lucknow
# 4         Hyderabad
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Transaction ID            1000 non-null   int64
#  1   Customer Name             1000 non-null   object
#  2   Merchant Name             1000 non-null   object
#  3   Transaction Date          1000 non-null   object
#  4   Transaction Amount (INR)  1000 non-null   int64
#  5   Fraud Risk                1000 non-null   object
#  6   Fraud Type                1000 non-null   object
#  7   State                     1000 non-null   object
#  8   Card Type                 1000 non-null   object
#  9   Bank                      1000 non-null   object
#  10  IsFraud                   1000 non-null   int64
#  11  Fraud Score               1000 non-null   int64
#  12  Transaction Category      1000 non-null   object
#  13  Merchant Location         1000 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 109.5+ KB
# None
# Transaction ID              0
# Customer Name               0
# Merchant Name               0
# Transaction Date            0
# Transaction Amount (INR)    0
# Fraud Risk                  0
# Fraud Type                  0
# State                       0
# Card Type                   0
# Bank                        0
# IsFraud                     0
# Fraud Score                 0
# Transaction Category        0
# Merchant Location           0
# dtype: int64
# 0

# %%
# Clean column Names
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
)

print(df.columns)
# Out:
# Index(['transaction_id', 'customer_name', 'merchant_name', 'transaction_date',
#        'transaction_amount_inr', 'fraud_risk', 'fraud_type', 'state',
#        'card_type', 'bank', 'isfraud', 'fraud_score', 'transaction_category',
#        'merchant_location'],
#       dtype='object')

# %%
# Convert Date Columns
df["transaction_date"] = pd.to_datetime(df["transaction_date"])
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  isfraud  fraud_score transaction_category  \
# 0       Rupay      ICICI Bank        0           57       Transportation
# 1        Amex             SBI        0           10            Groceries
# 2        Visa       HDFC Bank        0           55       Transportation
# 3        Visa    Federal Bank        0           30           E-commerce
# 4        Amex             SBI        0           86          Electronics
# ..        ...             ...      ...          ...                  ...
# 995      Visa             SBI        0           14              Apparel
# 996      Amex  Bank of Baroda        0           16          Electronics
# 997      Amex      ICICI Bank        0           43        Food Delivery
# 998      Amex     Andhra Bank        1           16       Transportation
# 999      Visa       HDFC Bank        0           82            Groceries
#
#     merchant_location
# 0           Bangalore
# 1           Bangalore
# 2           Ahmedabad
# 3             Lucknow
# 4           Hyderabad
# ..                ...
# 995           Lucknow
# 996           Chennai
# 997         Hyderabad
# 998         Hyderabad
# 999            Mumbai
#
# [1000 rows x 14 columns]

# %%
df["year"] = df["transaction_date"].dt.year
df["month_no"] = df["transaction_date"].dt.month
df["month_name"] = df["transaction_date"].dt.month_name()
df["quarter"] = df["transaction_date"].dt.quarter
df["day_name"] = df["transaction_date"].dt.day_name()
df["month_year"] = df["transaction_date"].dt.to_period("M").astype(str)
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  isfraud  fraud_score transaction_category  \
# 0       Rupay      ICICI Bank        0           57       Transportation
# 1        Amex             SBI        0           10            Groceries
# 2        Visa       HDFC Bank        0           55       Transportation
# 3        Visa    Federal Bank        0           30           E-commerce
# 4        Amex             SBI        0           86          Electronics
# ..        ...             ...      ...          ...                  ...
# 995      Visa             SBI        0           14              Apparel
# 996      Amex  Bank of Baroda        0           16          Electronics
# 997      Amex      ICICI Bank        0           43        Food Delivery
# 998      Amex     Andhra Bank        1           16       Transportation
# 999      Visa       HDFC Bank        0           82            Groceries
#
#     merchant_location  year  month_no month_name  quarter   day_name  \
# 0           Bangalore  2024        11   November        4     Sunday
# 1           Bangalore  2024         5        May        2     Monday
# 2           Ahmedabad  2024         5        May        2    Tuesday
# 3             Lucknow  2024         1    January        1    Tuesday
# 4           Hyderabad  2024         7       July        3   Saturday
# ..                ...   ...       ...        ...      ...        ...
# 995           Lucknow  2024         5        May        2   Thursday
# 996           Chennai  2024        10    October        4  Wednesday
# 997         Hyderabad  2024        11   November        4   Thursday
# 998         Hyderabad  2024         8     August        3     Friday
# 999            Mumbai  2024         5        May        2    Tuesday
#
#     month_year
# 0      2024-11
# 1      2024-05
# 2      2024-05
# 3      2024-01
# 4      2024-07
# ..         ...
# 995    2024-05
# 996    2024-10
# 997    2024-11
# 998    2024-08
# 999    2024-05
#
# [1000 rows x 20 columns]

# %%
df["fraud_type_clean"] = np.where(
    df["isfraud"] == 1,
    df["fraud_type"],
    "Not Fraud"
)
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  ...  fraud_score  transaction_category  \
# 0       Rupay      ICICI Bank  ...           57        Transportation
# 1        Amex             SBI  ...           10             Groceries
# 2        Visa       HDFC Bank  ...           55        Transportation
# 3        Visa    Federal Bank  ...           30            E-commerce
# 4        Amex             SBI  ...           86           Electronics
# ..        ...             ...  ...          ...                   ...
# 995      Visa             SBI  ...           14               Apparel
# 996      Amex  Bank of Baroda  ...           16           Electronics
# 997      Amex      ICICI Bank  ...           43         Food Delivery
# 998      Amex     Andhra Bank  ...           16        Transportation
# 999      Visa       HDFC Bank  ...           82             Groceries
#
#     merchant_location  year  month_no  month_name quarter   day_name  \
# 0           Bangalore  2024        11    November       4     Sunday
# 1           Bangalore  2024         5         May       2     Monday
# 2           Ahmedabad  2024         5         May       2    Tuesday
# 3             Lucknow  2024         1     January       1    Tuesday
# 4           Hyderabad  2024         7        July       3   Saturday
# ..                ...   ...       ...         ...     ...        ...
# 995           Lucknow  2024         5         May       2   Thursday
# 996           Chennai  2024        10     October       4  Wednesday
# 997         Hyderabad  2024        11    November       4   Thursday
# 998         Hyderabad  2024         8      August       3     Friday
# 999            Mumbai  2024         5         May       2    Tuesday
#
#     month_year  fraud_type_clean
# 0      2024-11         Not Fraud
# 1      2024-05         Not Fraud
# 2      2024-05         Not Fraud
# 3      2024-01         Not Fraud
# 4      2024-07         Not Fraud
# ..         ...               ...
# 995    2024-05         Not Fraud
# 996    2024-10         Not Fraud
# 997    2024-11         Not Fraud
# 998    2024-08  Account Takeover
# 999    2024-05         Not Fraud
#
# [1000 rows x 21 columns]

# %%
df["amount_bucket"] = pd.cut(
    df["transaction_amount_inr"],
    bins=[0, 5000, 10000, 15000, 20000, 25000],
    labels=["0-5K", "5K-10K", "10K-15K", "15K-20K", "20K-25K"]
)
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  ...  transaction_category  merchant_location  \
# 0       Rupay      ICICI Bank  ...        Transportation          Bangalore
# 1        Amex             SBI  ...             Groceries          Bangalore
# 2        Visa       HDFC Bank  ...        Transportation          Ahmedabad
# 3        Visa    Federal Bank  ...            E-commerce            Lucknow
# 4        Amex             SBI  ...           Electronics          Hyderabad
# ..        ...             ...  ...                   ...                ...
# 995      Visa             SBI  ...               Apparel            Lucknow
# 996      Amex  Bank of Baroda  ...           Electronics            Chennai
# 997      Amex      ICICI Bank  ...         Food Delivery          Hyderabad
# 998      Amex     Andhra Bank  ...        Transportation          Hyderabad
# 999      Visa       HDFC Bank  ...             Groceries             Mumbai
#
#      year month_no  month_name  quarter   day_name  month_year  \
# 0    2024       11    November        4     Sunday     2024-11
# 1    2024        5         May        2     Monday     2024-05
# 2    2024        5         May        2    Tuesday     2024-05
# 3    2024        1     January        1    Tuesday     2024-01
# 4    2024        7        July        3   Saturday     2024-07
# ..    ...      ...         ...      ...        ...         ...
# 995  2024        5         May        2   Thursday     2024-05
# 996  2024       10     October        4  Wednesday     2024-10
# 997  2024       11    November        4   Thursday     2024-11
# 998  2024        8      August        3     Friday     2024-08
# 999  2024        5         May        2    Tuesday     2024-05
#
#      fraud_type_clean amount_bucket
# 0           Not Fraud       10K-15K
# 1           Not Fraud       15K-20K
# 2           Not Fraud       20K-25K
# 3           Not Fraud       20K-25K
# 4           Not Fraud        5K-10K
# ..                ...           ...
# 995         Not Fraud          0-5K
# 996         Not Fraud       10K-15K
# 997         Not Fraud       20K-25K
# 998  Account Takeover       15K-20K
# 999         Not Fraud       15K-20K
#
# [1000 rows x 22 columns]

# %%
df["fraud_score_bucket"] = pd.cut(
    df["fraud_score"],
    bins=[0, 25, 50, 75, 100],
    labels=["Low Score", "Medium Score", "High Score", "Very High Score"]
)
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  ...  merchant_location  year month_no  \
# 0       Rupay      ICICI Bank  ...          Bangalore  2024       11
# 1        Amex             SBI  ...          Bangalore  2024        5
# 2        Visa       HDFC Bank  ...          Ahmedabad  2024        5
# 3        Visa    Federal Bank  ...            Lucknow  2024        1
# 4        Amex             SBI  ...          Hyderabad  2024        7
# ..        ...             ...  ...                ...   ...      ...
# 995      Visa             SBI  ...            Lucknow  2024        5
# 996      Amex  Bank of Baroda  ...            Chennai  2024       10
# 997      Amex      ICICI Bank  ...          Hyderabad  2024       11
# 998      Amex     Andhra Bank  ...          Hyderabad  2024        8
# 999      Visa       HDFC Bank  ...             Mumbai  2024        5
#
#     month_name  quarter   day_name month_year  fraud_type_clean amount_bucket  \
# 0     November        4     Sunday    2024-11         Not Fraud       10K-15K
# 1          May        2     Monday    2024-05         Not Fraud       15K-20K
# 2          May        2    Tuesday    2024-05         Not Fraud       20K-25K
# 3      January        1    Tuesday    2024-01         Not Fraud       20K-25K
# 4         July        3   Saturday    2024-07         Not Fraud        5K-10K
# ..         ...      ...        ...        ...               ...           ...
# 995        May        2   Thursday    2024-05         Not Fraud          0-5K
# 996    October        4  Wednesday    2024-10         Not Fraud       10K-15K
# 997   November        4   Thursday    2024-11         Not Fraud       20K-25K
# 998     August        3     Friday    2024-08  Account Takeover       15K-20K
# 999        May        2    Tuesday    2024-05         Not Fraud       15K-20K
#
#     fraud_score_bucket
# 0           High Score
# 1            Low Score
# 2           High Score
# 3         Medium Score
# 4      Very High Score
# ..                 ...
# 995          Low Score
# 996          Low Score
# 997       Medium Score
# 998          Low Score
# 999    Very High Score
#
# [1000 rows x 23 columns]

# %%
risk_map = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

df["risk_rank"] = df["fraud_risk"].map(risk_map)
df
# Out:
#      transaction_id  customer_name merchant_name transaction_date  \
# 0          17797619     Pihu Manne          Uber       2024-11-10
# 1          50040671   Hiran Vaidya        Zomato       2024-05-20
# 2          88177651     Shalv Vasa        Myntra       2024-05-28
# 3          24228305  Taran Shanker     Lifestyle       2024-01-09
# 4          87307869   Shanaya Kara     Tata Cliq       2024-07-27
# ..              ...            ...           ...              ...
# 995        97151229   Nitya Ganesh      Flipkart       2024-05-09
# 996        46529985    Shray Dubey     Lifestyle       2024-10-02
# 997        10160858    Kaira Kumar     Tata Cliq       2024-11-21
# 998        48484987      Rati Date     Lifestyle       2024-08-30
# 999        20156336    Baiju Dubey          Uber       2024-05-07
#
#      transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                     11673     Medium  Card Not Present      Telangana
# 1                     16594     Medium          Phishing    Maharashtra
# 2                     23347     Medium     Card Skimming  Uttar Pradesh
# 3                     20753        Low     Card Skimming         Kerala
# 4                      6432        Low     Card Skimming          Delhi
# ..                      ...        ...               ...            ...
# 995                    2834     Medium  Account Takeover      Rajasthan
# 996                   12740        Low          Phishing    Maharashtra
# 997                   20057   Critical          Phishing    West Bengal
# 998                   19933       High  Account Takeover         Kerala
# 999                   17105     Medium          Phishing    Maharashtra
#
#     card_type            bank  ...  year  month_no month_name quarter  \
# 0       Rupay      ICICI Bank  ...  2024        11   November       4
# 1        Amex             SBI  ...  2024         5        May       2
# 2        Visa       HDFC Bank  ...  2024         5        May       2
# 3        Visa    Federal Bank  ...  2024         1    January       1
# 4        Amex             SBI  ...  2024         7       July       3
# ..        ...             ...  ...   ...       ...        ...     ...
# 995      Visa             SBI  ...  2024         5        May       2
# 996      Amex  Bank of Baroda  ...  2024        10    October       4
# 997      Amex      ICICI Bank  ...  2024        11   November       4
# 998      Amex     Andhra Bank  ...  2024         8     August       3
# 999      Visa       HDFC Bank  ...  2024         5        May       2
#
#       day_name  month_year  fraud_type_clean  amount_bucket  \
# 0       Sunday     2024-11         Not Fraud        10K-15K
# 1       Monday     2024-05         Not Fraud        15K-20K
# 2      Tuesday     2024-05         Not Fraud        20K-25K
# 3      Tuesday     2024-01         Not Fraud        20K-25K
# 4     Saturday     2024-07         Not Fraud         5K-10K
# ..         ...         ...               ...            ...
# 995   Thursday     2024-05         Not Fraud           0-5K
# 996  Wednesday     2024-10         Not Fraud        10K-15K
# 997   Thursday     2024-11         Not Fraud        20K-25K
# 998     Friday     2024-08  Account Takeover        15K-20K
# 999    Tuesday     2024-05         Not Fraud        15K-20K
#
#     fraud_score_bucket risk_rank
# 0           High Score         2
# 1            Low Score         2
# 2           High Score         2
# 3         Medium Score         1
# 4      Very High Score         1
# ..                 ...       ...
# 995          Low Score         2
# 996          Low Score         1
# 997       Medium Score         4
# 998          Low Score         3
# 999    Very High Score         2
#
# [1000 rows x 24 columns]

# %%
total_transactions = df["transaction_id"].count()
fraud_transactions = df["isfraud"].sum()
fraud_rate = fraud_transactions / total_transactions
total_amount = df["transaction_amount_inr"].sum()
fraud_amount = df.loc[df["isfraud"] == 1, "transaction_amount_inr"].sum()

print("Total Transactions:", total_transactions)
print("Fraud Transactions:", fraud_transactions)
print("Fraud Rate:", round(fraud_rate * 100, 2), "%")
print("Total Amount:", total_amount)
print("Fraud Amount:", fraud_amount)
# Out:
# Total Transactions: 1000
# Fraud Transactions: 286
# Fraud Rate: 28.6 %
# Total Amount: 12226843
# Fraud Amount: 3306813

# %%
category_fraud = df.groupby("transaction_category").agg(
    total_transactions=("transaction_id", "count"),
    fraud_transactions=("isfraud", "sum"),
    total_amount=("transaction_amount_inr", "sum")
)

category_fraud["fraud_rate"] = (
    category_fraud["fraud_transactions"] / category_fraud["total_transactions"] * 100
)

category_fraud.sort_values("fraud_rate", ascending=False)
# Out:
#                       total_transactions  fraud_transactions  total_amount  \
# transaction_category
# Food Delivery                        148                  48       1804118
# E-commerce                           174                  54       2125395
# Electronics                          179                  54       1993079
# Apparel                              162                  44       2014873
# Groceries                            154                  41       1877974
# Transportation                       183                  45       2411404
#
#                       fraud_rate
# transaction_category
# Food Delivery          32.432432
# E-commerce             31.034483
# Electronics            30.167598
# Apparel                27.160494
# Groceries              26.623377
# Transportation         24.590164

# %%
state_fraud = df.groupby("state").agg(
    total_transactions=("transaction_id", "count"),
    fraud_transactions=("isfraud", "sum")
)

state_fraud["fraud_rate"] = (
    state_fraud["fraud_transactions"] / state_fraud["total_transactions"] * 100
)

state_fraud.sort_values("fraud_rate", ascending=False)
# Out:
#                total_transactions  fraud_transactions  fraud_rate
# state
# Karnataka                      96                  34   35.416667
# Maharashtra                   107                  36   33.644860
# West Bengal                   104                  33   31.730769
# Rajasthan                     113                  34   30.088496
# Uttar Pradesh                 100                  29   29.000000
# Telangana                      98                  27   27.551020
# Tamil Nadu                    102                  28   27.450980
# Gujarat                        94                  23   24.468085
# Delhi                          92                  21   22.826087
# Kerala                         94                  21   22.340426

# %%
card_fraud = df.groupby("card_type").agg(
    total_transactions=("transaction_id", "count"),
    fraud_transactions=("isfraud", "sum")
)

card_fraud["fraud_rate"] = (
    card_fraud["fraud_transactions"] / card_fraud["total_transactions"] * 100
)

card_fraud.sort_values("fraud_rate", ascending=False)
# Out:
#             total_transactions  fraud_transactions  fraud_rate
# card_type
# Visa                       261                  88   33.716475
# Mastercard                 237                  66   27.848101
# Amex                       255                  71   27.843137
# Rupay                      247                  61   24.696356

# %%
df.to_csv("clean_credit_card_fraud_analysis.csv", index=False)

# %%
import pyodbc
server = "DESKTOP-BND2C7N"   
database = "Fraud_Analysis"            

conn = pyodbc.connect(
    f"DRIVER={{ODBC Driver 18 for SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
    f"TrustServerCertificate=yes;"
)

print("Connected successfully")
# Out:
# Connected successfully

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

server = "DESKTOP-BND2C7N"   
database = "Fraud_Analysis"            

connection_string = quote_plus(
    f"DRIVER={{ODBC Driver 18 for SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"Trusted_Connection=yes;"
    f"TrustServerCertificate=yes;"
)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={connection_string}")

# %%
df.to_sql(
    name="clean_credit_card_fraud_analysis",
    con=engine,
    schema="dbo",
    if_exists="replace",
    index=False
)
# Out:
# -1

# %%
check_df = pd.read_sql(
    "SELECT TOP 10 * FROM dbo.clean_credit_card_fraud_analysis",
    con=engine
)

check_df.head()
# Out:
#    transaction_id  customer_name merchant_name transaction_date  \
# 0        17797619     Pihu Manne          Uber       2024-11-10
# 1        50040671   Hiran Vaidya        Zomato       2024-05-20
# 2        88177651     Shalv Vasa        Myntra       2024-05-28
# 3        24228305  Taran Shanker     Lifestyle       2024-01-09
# 4        87307869   Shanaya Kara     Tata Cliq       2024-07-27
#
#    transaction_amount_inr fraud_risk        fraud_type          state  \
# 0                   11673     Medium  Card Not Present      Telangana
# 1                   16594     Medium          Phishing    Maharashtra
# 2                   23347     Medium     Card Skimming  Uttar Pradesh
# 3                   20753        Low     Card Skimming         Kerala
# 4                    6432        Low     Card Skimming          Delhi
#
#   card_type          bank  ...  year  month_no month_name quarter  day_name  \
# 0     Rupay    ICICI Bank  ...  2024        11   November       4    Sunday
# 1      Amex           SBI  ...  2024         5        May       2    Monday
# 2      Visa     HDFC Bank  ...  2024         5        May       2   Tuesday
# 3      Visa  Federal Bank  ...  2024         1    January       1   Tuesday
# 4      Amex           SBI  ...  2024         7       July       3  Saturday
#
#    month_year fraud_type_clean  amount_bucket fraud_score_bucket risk_rank
# 0     2024-11        Not Fraud        10K-15K         High Score         2
# 1     2024-05        Not Fraud        15K-20K          Low Score         2
# 2     2024-05        Not Fraud        20K-25K         High Score         2
# 3     2024-01        Not Fraud        20K-25K       Medium Score         1
# 4     2024-07        Not Fraud         5K-10K    Very High Score         1
#
# [5 rows x 24 columns]
